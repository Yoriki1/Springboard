# %% [markdown]
# # DIA Capstone

# %% [markdown]
# ## 1. Data

# %% [markdown]
# ### 1a. Load relevant libraries

# %%
import pandas as pd
import math
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import math

# %% [markdown]
# ### 1b. Load the data

# %%
DIA = pd.read_csv('DIA (3).csv')

# %% [markdown]
# ## 2. Data Wrangling

# %%
DIA.head()
# Out:
#        Date        Open        High         Low       Close   Adj Close  \
# 0  1/2/2015  178.649994  179.229996  176.979996  177.940002  153.454803
# 1  1/5/2015  177.059998  177.210007  174.460007  174.839996  150.781387
# 2  1/6/2015  175.100006  175.539993  172.320007  173.389999  149.530914
# 3  1/7/2015  174.850006  175.789993  174.240005  175.589996  151.428162
# 4  1/8/2015  177.259995  178.960007  177.210007  178.759995  154.161942
#
#      Volume
# 0   4997200
# 1   6700200
# 2  10131400
# 3   5547000
# 4   7166700

# %%
DIA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1257 non-null   object
#  1   Open       1257 non-null   float64
#  2   High       1257 non-null   float64
#  3   Low        1257 non-null   float64
#  4   Close      1257 non-null   float64
#  5   Adj Close  1257 non-null   float64
#  6   Volume     1257 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %%
DIA['Date'] = pd.to_datetime(DIA['Date'])

# %%
DIA = DIA.set_index('Date').asfreq('B').ffill()

# %%
DIA['% Change in Price'] = DIA['Adj Close'].pct_change()

# %%
DIA['% Change in Volume'] = DIA['Adj Close'].pct_change()

# %% [markdown]
# ## 3. EDA

# %%
DIA['Adj Close'].describe()
# Out:
# count    1302.000000
# mean      199.534848
# std        40.306973
# min       136.997742
# 25%       157.495525
# 50%       195.819824
# 75%       236.760735
# max       276.615112
# Name: Adj Close, dtype: float64

# %%
_ = DIA['Adj Close'].plot()
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
_ = DIA['Adj Close'].plot(kind = 'hist')
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
_ = DIA['Adj Close'].plot(kind = 'kde')
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
DIA['Volume'].describe()
# Out:
# count    1.302000e+03
# mean     4.372181e+06
# std      2.853058e+06
# min      6.116000e+05
# 25%      2.511075e+06
# 50%      3.651900e+06
# 75%      5.376775e+06
# max      3.510240e+07
# Name: Volume, dtype: float64

# %%
_ = DIA['Volume'].plot()

# %%
_ = DIA['% Change in Price'].plot()
plt.ylabel('Change')
# Out:
# Text(0, 0.5, 'Change')

# %%
_ = DIA['% Change in Price'].plot(kind = 'hist')
plt.xlabel('Change')
# Out:
# Text(0.5, 0, 'Change')

# %%
_ = DIA['% Change in Price'].plot(kind = 'kde')
plt.xlabel('Change')
# Out:
# Text(0.5, 0, 'Change')

# %%
_ = DIA['% Change in Volume'].plot()

# %%
DIA['% Change in Volume'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## 4. Preprocessing and Modeling

# %% [markdown]
# ### 4a. Train-Test Split

# %%
y = DIA['Adj Close']

# %%
    split=int(len(y) * 0.65) 
    # Make train and test variables, with 'train, test'
    train, test = y[0:split], y[split:len(y)]

# %%
plt.plot(train)
plt.plot(test)
plt.xlabel('Date')
plt.ylabel('Adj Close')
plt.title('Train Test Split')
plt.show()

# %% [markdown]
# ### 4b. Arima

# %% [markdown]
# ### 4bi. Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(y)

trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot the original data, the trend, the seasonality, and the residuals 
plt.subplot(411)
plt.plot(y, label = 'Original')
plt.legend(loc = 'best')
plt.subplot(412)
plt.plot(trend, label = 'Trend')
plt.legend(loc = 'best')
plt.subplot(413)
plt.plot(seasonal, label = "Seasonality")
plt.legend(loc = 'best')
plt.subplot(414)
plt.plot(residual, label = "Residual")
plt.tight_layout()

# %% [markdown]
# ### 4bii. Stationarity

# %%
from statsmodels.tsa.stattools import kpss
kpss(y)
# Out:
# C:\Users\yorik\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1875: FutureWarning: The behavior of using nlags=None will change in release 0.13.Currently nlags=None is the same as nlags="legacy", and so a sample-size lag length is used. After the next release, the default will change to be the same as nlags="auto" which uses an automatic lag length selection method. To silence this warning, either use "auto" or "legacy"
#   warnings.warn(msg, FutureWarning)
# C:\Users\yorik\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1906: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   warnings.warn(
# (5.3803298534460815,
#  0.01,
#  23,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %%
y_log = np.log(y)

# %%
_ = plt.figure(figsize=(10,5))
_ = plt.plot(y_log.diff())

# %%
kpss(y_log.diff().dropna())
# Out:
# C:\Users\yorik\anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:1910: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   warnings.warn(
# (0.08738928379019296,
#  0.1,
#  23,
#  {'10%': 0.347, '5%': 0.463, '2.5%': 0.574, '1%': 0.739})

# %% [markdown]
# ### 4.biii ARIMA model

# %%
# Make a function called evaluate_arima_model to find the MSE of a single ARIMA model 
def evaluate_arima_model(data, arima_order):
    split=int(len(data) * 0.65) 
    # Make train and test variables, with 'train, test'
    train, test = data[0:split], data[split:len(data)]
    past=[x for x in train]
    # make predictions
    predictions = list()
    for i in range(len(test)):
        model = ARIMA(past, order=arima_order)
        model_fit = model.fit(disp=0)
        future = model_fit.forecast()[0]
        predictions.append(future)
        past.append(test[i])
    # calculate out of sample error
    error = mean_squared_error(test, predictions)
    # Return the error
    return error

# %%
# Make a function called evaluate_models to evaluate different ARIMA models with several different p, d, and q values.
def evaluate_models(dataset, p_values, d_values, q_values):
    best_score, best_cfg = float("inf"), None
    # Iterate through p_values
    for p in p_values:
        # Iterate through d_values
        for d in d_values:
            # Iterate through q_values
            for q in q_values:
                # p, d, q iterator variables
                order = (p,d,q)
                try:
                    # Make a variable called mse for the Mean squared error
                    mse = evaluate_arima_model(dataset, order)
                    if mse < best_score:
                        best_score, best_cfg = mse, order
                    print('ARIMA%s MSE=%.6f' % (order,mse))
                except:
                    continue
    return print('Best ARIMA%s MSE=%.6f' % (best_cfg, best_score))

# %%
p_values = [x for x in range(0, 3)]
d_values = [x for x in range(0, 3)]
q_values = [x for x in range(0, 3)]

# %%
import warnings
warnings.filterwarnings("ignore")
evaluate_models(y_log, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) MSE=0.078598
# ARIMA(0, 0, 1) MSE=0.020535
# ARIMA(0, 1, 0) MSE=0.000080
# ARIMA(0, 1, 1) MSE=0.000080
# ARIMA(0, 1, 2) MSE=0.000081
# ARIMA(0, 2, 0) MSE=0.000159
# ARIMA(0, 2, 1) MSE=0.000081
# ARIMA(0, 2, 2) MSE=0.000081
# ARIMA(1, 0, 0) MSE=0.000081
# ARIMA(1, 1, 0) MSE=0.000080
# ARIMA(1, 1, 1) MSE=0.000081
# ARIMA(1, 1, 2) MSE=0.000081
# ARIMA(1, 2, 0) MSE=0.000121
# ARIMA(2, 0, 0) MSE=57123.249223
# ARIMA(2, 1, 0) MSE=0.000081
# ARIMA(2, 1, 1) MSE=0.000081
# ARIMA(2, 1, 2) MSE=0.000082
# ARIMA(2, 2, 0) MSE=0.000109
# ARIMA(2, 2, 1) MSE=0.000081
# ARIMA(2, 2, 2) MSE=0.000082
# Best ARIMA(0, 1, 0) MSE=0.000080

# %% [markdown]
# ### 4.bvi Best ARIMA model

# %%
p=0
d=1
q=0
model = ARIMA(y_log, order=(p,d,q))
model_fit = model.fit()
forecast = model_fit.forecast(12)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D.Adj Close   No. Observations:                 1301
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                4374.443
# Method:                           css   S.D. of innovations              0.008
# Date:                Thu, 02 Dec 2021   AIC                          -8744.885
# Time:                        12:18:58   BIC                          -8734.543
# Sample:                    01-05-2015   HQIC                         -8741.005
#                          - 12-30-2019
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.927      0.054   -7.58e-06       0.001
# ==============================================================================
# """

# %%
# Call figure() and plot() on the plt
plt.figure(figsize=(15,10))
plt.plot(y_log.diff())
plt.plot(model_fit.predict(), color = 'red')

# %%
forecast_period = 12
date_range = pd.date_range(y_log.index[-1], periods = forecast_period, \
                           freq='D').strftime("%Y-%m-%d").tolist()

future_dates = pd.DataFrame(date_range, columns = ['Date'])
future_dates['Date'] = pd.to_datetime(future_dates['Date'])
future_dates.set_index('Date', inplace = True)
future_dates['Prediction'] = forecast[0]


plt.figure(figsize=(15,10))
plt.plot(y)
plt.plot(y['2019'].append(np.exp(future_dates['Prediction'])))
plt.show()

# %% [markdown]
# ## 4c. LSTM

# %%
y.head()
# Out:
# Date
# 2015-01-02    153.454803
# 2015-01-05    150.781387
# 2015-01-06    149.530914
# 2015-01-07    151.428162
# 2015-01-08    154.161942
# Freq: B, Name: Adj Close, dtype: float64

# %%
plt.plot(y)
plt.show()

# %% [markdown]
# ### 4ci. Scaling

# %%
# Scaling the data since LSTM is sensitive to the scale of the data
scaler=MinMaxScaler(feature_range=(0,1))
y=scaler.fit_transform(np.array(y).reshape(-1,1))

# %%
y
# Out:
# array([[0.11787259],
#        [0.09872443],
#        [0.089768  ],
#        ...,
#        [0.99813202],
#        [1.        ],
#        [0.98754509]])

# %% [markdown]
# ### 4. cii LSTM model

# %%
# train , test split
training_size=int(len(y)*0.65)
test_size=len(y)-training_size
train_data,test_data=y[0:training_size,:],y[training_size:len(y),:1]

# %%
training_size,test_size
# Out:
# (846, 456)

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
X_train.shape, y_train.shape
# Out:
# ((745, 100), (745,))

# %%
X_test.shape, y_test.shape
# Out:
# ((355, 100), (355,))

# %%
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 19s 533ms/step - loss: 0.0359 - val_loss: 0.0465
# Epoch 2/100
# 12/12 [==============================] - 3s 280ms/step - loss: 0.0057 - val_loss: 0.0048
# Epoch 3/100
# 12/12 [==============================] - 3s 272ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 4/100
# 12/12 [==============================] - 3s 244ms/step - loss: 9.8953e-04 - val_loss: 0.0023
# Epoch 5/100
# 12/12 [==============================] - 3s 254ms/step - loss: 8.2997e-04 - val_loss: 0.0025
# Epoch 6/100
# 12/12 [==============================] - 3s 277ms/step - loss: 7.9031e-04 - val_loss: 0.0026
# Epoch 7/100
# 12/12 [==============================] - 3s 271ms/step - loss: 7.7203e-04 - val_loss: 0.0022
# Epoch 8/100
# 12/12 [==============================] - 3s 285ms/step - loss: 7.5620e-04 - val_loss: 0.0023
# Epoch 9/100
# 12/12 [==============================] - 3s 225ms/step - loss: 7.4328e-04 - val_loss: 0.0021
# Epoch 10/100
# 12/12 [==============================] - 3s 238ms/step - loss: 7.9193e-04 - val_loss: 0.0022
# Epoch 11/100
# 12/12 [==============================] - 3s 263ms/step - loss: 7.3290e-04 - val_loss: 0.0023
# Epoch 12/100
# 12/12 [==============================] - 3s 266ms/step - loss: 7.1479e-04 - val_loss: 0.0023
# Epoch 13/100
# 12/12 [==============================] - 3s 278ms/step - loss: 7.0225e-04 - val_loss: 0.0024
# Epoch 14/100
# 12/12 [==============================] - 3s 209ms/step - loss: 7.0214e-04 - val_loss: 0.0024
# Epoch 15/100
# 12/12 [==============================] - 3s 272ms/step - loss: 6.9324e-04 - val_loss: 0.0023
# Epoch 16/100
# 12/12 [==============================] - 3s 274ms/step - loss: 6.8946e-04 - val_loss: 0.0024
# Epoch 17/100
# 12/12 [==============================] - 3s 251ms/step - loss: 6.6154e-04 - val_loss: 0.0032
# Epoch 18/100
# 12/12 [==============================] - 3s 254ms/step - loss: 6.7270e-04 - val_loss: 0.0024
# Epoch 19/100
# 12/12 [==============================] - 3s 219ms/step - loss: 6.6773e-04 - val_loss: 0.0021
# Epoch 20/100
# 12/12 [==============================] - 3s 260ms/step - loss: 6.6738e-04 - val_loss: 0.0020
# Epoch 21/100
# 12/12 [==============================] - 3s 226ms/step - loss: 6.3914e-04 - val_loss: 0.0028
# Epoch 22/100
# 12/12 [==============================] - 3s 218ms/step - loss: 6.5106e-04 - val_loss: 0.0019
# Epoch 23/100
# 12/12 [==============================] - 3s 244ms/step - loss: 6.3797e-04 - val_loss: 0.0023
# Epoch 24/100
# 12/12 [==============================] - 3s 292ms/step - loss: 6.6743e-04 - val_loss: 0.0022
# Epoch 25/100
# 12/12 [==============================] - 4s 301ms/step - loss: 6.4384e-04 - val_loss: 0.0022
# Epoch 26/100
# 12/12 [==============================] - 4s 300ms/step - loss: 5.9174e-04 - val_loss: 0.0025
# Epoch 27/100
# 12/12 [==============================] - 4s 304ms/step - loss: 6.2203e-04 - val_loss: 0.0019
# Epoch 28/100
# 12/12 [==============================] - 4s 346ms/step - loss: 5.9748e-04 - val_loss: 0.0016
# Epoch 29/100
# 12/12 [==============================] - 4s 351ms/step - loss: 5.6810e-04 - val_loss: 0.0018
# Epoch 30/100
# 12/12 [==============================] - 4s 319ms/step - loss: 5.5828e-04 - val_loss: 0.0020
# Epoch 31/100
# 12/12 [==============================] - 4s 318ms/step - loss: 5.7767e-04 - val_loss: 0.0016
# Epoch 32/100
# 12/12 [==============================] - 4s 298ms/step - loss: 5.6150e-04 - val_loss: 0.0016
# Epoch 33/100
# 12/12 [==============================] - 4s 304ms/step - loss: 5.8251e-04 - val_loss: 0.0020
# Epoch 34/100
# 12/12 [==============================] - 4s 309ms/step - loss: 6.2996e-04 - val_loss: 0.0015
# Epoch 35/100
# 12/12 [==============================] - 4s 302ms/step - loss: 6.9595e-04 - val_loss: 0.0037
# Epoch 36/100
# 12/12 [==============================] - 4s 309ms/step - loss: 5.8516e-04 - val_loss: 0.0017
# Epoch 37/100
# 12/12 [==============================] - 4s 304ms/step - loss: 6.4361e-04 - val_loss: 0.0021
# Epoch 38/100
# 12/12 [==============================] - 4s 298ms/step - loss: 5.4194e-04 - val_loss: 0.0014
# Epoch 39/100
# 12/12 [==============================] - 4s 299ms/step - loss: 5.2601e-04 - val_loss: 0.0015
# Epoch 40/100
# 12/12 [==============================] - 4s 308ms/step - loss: 5.3870e-04 - val_loss: 0.0025
# Epoch 41/100
# 12/12 [==============================] - 4s 301ms/step - loss: 5.5649e-04 - val_loss: 0.0016
# Epoch 42/100
# 12/12 [==============================] - 4s 298ms/step - loss: 5.1664e-04 - val_loss: 0.0018
# Epoch 43/100
# 12/12 [==============================] - 4s 312ms/step - loss: 4.9814e-04 - val_loss: 0.0025
# Epoch 44/100
# 12/12 [==============================] - 4s 306ms/step - loss: 5.4347e-04 - val_loss: 0.0013
# Epoch 45/100
# 12/12 [==============================] - 4s 314ms/step - loss: 5.0473e-04 - val_loss: 0.0018
# Epoch 46/100
# 12/12 [==============================] - 4s 319ms/step - loss: 4.9300e-04 - val_loss: 0.0013
# Epoch 47/100
# 12/12 [==============================] - 4s 309ms/step - loss: 5.1143e-04 - val_loss: 0.0035
# Epoch 48/100
# 12/12 [==============================] - 4s 308ms/step - loss: 5.2572e-04 - val_loss: 0.0012
# Epoch 49/100
# 12/12 [==============================] - 4s 298ms/step - loss: 4.6201e-04 - val_loss: 0.0017
# Epoch 50/100
# 12/12 [==============================] - 4s 303ms/step - loss: 4.5347e-04 - val_loss: 0.0017
# Epoch 51/100
# 12/12 [==============================] - 4s 308ms/step - loss: 4.5775e-04 - val_loss: 0.0017
# Epoch 52/100
# 12/12 [==============================] - 3s 266ms/step - loss: 4.4494e-04 - val_loss: 0.0012
# Epoch 53/100
# 12/12 [==============================] - 3s 274ms/step - loss: 4.9047e-04 - val_loss: 0.0013
# Epoch 54/100
# 12/12 [==============================] - 3s 272ms/step - loss: 4.5378e-04 - val_loss: 0.0021
# Epoch 55/100
# 12/12 [==============================] - 3s 285ms/step - loss: 4.2882e-04 - val_loss: 0.0016
# Epoch 56/100
# 12/12 [==============================] - 3s 278ms/step - loss: 4.3479e-04 - val_loss: 0.0013
# Epoch 57/100
# 12/12 [==============================] - 3s 279ms/step - loss: 4.5244e-04 - val_loss: 0.0011
# Epoch 58/100
# 12/12 [==============================] - 3s 270ms/step - loss: 4.2920e-04 - val_loss: 0.0018
# Epoch 59/100
# 12/12 [==============================] - 3s 276ms/step - loss: 4.1985e-04 - val_loss: 0.0015
# Epoch 60/100
# 12/12 [==============================] - 3s 265ms/step - loss: 4.6261e-04 - val_loss: 0.0029
# Epoch 61/100
# 12/12 [==============================] - 3s 283ms/step - loss: 5.7595e-04 - val_loss: 0.0011
# Epoch 62/100
# 12/12 [==============================] - 3s 273ms/step - loss: 4.4753e-04 - val_loss: 0.0014
# Epoch 63/100
# 12/12 [==============================] - 3s 259ms/step - loss: 4.2418e-04 - val_loss: 0.0023
# Epoch 64/100
# 12/12 [==============================] - 3s 282ms/step - loss: 4.6561e-04 - val_loss: 0.0015
# Epoch 65/100
# 12/12 [==============================] - 3s 273ms/step - loss: 4.0970e-04 - val_loss: 0.0012
# Epoch 66/100
# 12/12 [==============================] - 3s 289ms/step - loss: 3.9373e-04 - val_loss: 0.0024
# Epoch 67/100
# 12/12 [==============================] - 4s 304ms/step - loss: 4.0684e-04 - val_loss: 0.0020
# Epoch 68/100
# 12/12 [==============================] - 3s 294ms/step - loss: 3.9872e-04 - val_loss: 0.0012
# Epoch 69/100
# 12/12 [==============================] - 4s 295ms/step - loss: 4.0902e-04 - val_loss: 0.0016
# Epoch 70/100
# 12/12 [==============================] - 3s 290ms/step - loss: 4.0294e-04 - val_loss: 0.0025
# Epoch 71/100
# 12/12 [==============================] - 4s 303ms/step - loss: 4.2997e-04 - val_loss: 0.0014
# Epoch 72/100
# 12/12 [==============================] - 4s 306ms/step - loss: 3.5972e-04 - val_loss: 0.0016
# Epoch 73/100
# 12/12 [==============================] - 4s 299ms/step - loss: 3.6431e-04 - val_loss: 0.0017
# Epoch 74/100
# 12/12 [==============================] - 4s 298ms/step - loss: 3.6816e-04 - val_loss: 0.0020
# Epoch 75/100
# 12/12 [==============================] - 3s 292ms/step - loss: 3.7945e-04 - val_loss: 0.0011
# Epoch 76/100
# 12/12 [==============================] - 4s 316ms/step - loss: 3.7209e-04 - val_loss: 0.0024
# Epoch 77/100
# 12/12 [==============================] - 4s 310ms/step - loss: 3.6930e-04 - val_loss: 0.0016
# Epoch 78/100
# 12/12 [==============================] - 4s 303ms/step - loss: 3.5556e-04 - val_loss: 0.0025
# Epoch 79/100
# 12/12 [==============================] - 4s 295ms/step - loss: 3.5222e-04 - val_loss: 0.0022
# Epoch 80/100
# 12/12 [==============================] - 4s 313ms/step - loss: 4.3572e-04 - val_loss: 0.0023
# Epoch 81/100
# 12/12 [==============================] - 4s 315ms/step - loss: 3.9001e-04 - val_loss: 0.0011
# Epoch 82/100
# 12/12 [==============================] - 4s 319ms/step - loss: 3.6630e-04 - val_loss: 0.0015
# Epoch 83/100
# 12/12 [==============================] - 4s 299ms/step - loss: 3.4701e-04 - val_loss: 0.0014
# Epoch 84/100
# 12/12 [==============================] - 4s 303ms/step - loss: 3.5241e-04 - val_loss: 0.0023
# Epoch 85/100
# 12/12 [==============================] - 4s 300ms/step - loss: 3.7225e-04 - val_loss: 0.0014
# Epoch 86/100
# 12/12 [==============================] - 4s 304ms/step - loss: 3.1928e-04 - val_loss: 0.0016
# Epoch 87/100
# 12/12 [==============================] - 4s 308ms/step - loss: 3.1555e-04 - val_loss: 0.0019
# Epoch 88/100
# 12/12 [==============================] - 3s 290ms/step - loss: 3.2992e-04 - val_loss: 0.0016
# Epoch 89/100
# 12/12 [==============================] - 4s 307ms/step - loss: 3.4969e-04 - val_loss: 0.0029
# Epoch 90/100
# 12/12 [==============================] - 4s 308ms/step - loss: 3.4513e-04 - val_loss: 0.0018
# Epoch 91/100
# 12/12 [==============================] - 4s 317ms/step - loss: 3.6949e-04 - val_loss: 0.0023
# Epoch 92/100
# 12/12 [==============================] - 4s 297ms/step - loss: 3.5161e-04 - val_loss: 0.0013
# Epoch 93/100
# 12/12 [==============================] - 4s 313ms/step - loss: 3.1597e-04 - val_loss: 0.0020
# Epoch 94/100
# 12/12 [==============================] - 4s 317ms/step - loss: 3.7228e-04 - val_loss: 0.0054
# Epoch 95/100
# 12/12 [==============================] - 4s 320ms/step - loss: 4.5344e-04 - val_loss: 0.0010
# Epoch 96/100
# 12/12 [==============================] - 4s 313ms/step - loss: 3.1579e-04 - val_loss: 0.0015
# Epoch 97/100
# 12/12 [==============================] - 3s 288ms/step - loss: 3.2161e-04 - val_loss: 0.0021
# Epoch 98/100
# 12/12 [==============================] - 4s 308ms/step - loss: 3.1145e-04 - val_loss: 0.0014
# Epoch 99/100
# 12/12 [==============================] - 4s 308ms/step - loss: 3.2247e-04 - val_loss: 0.0020
# Epoch 100/100
# 12/12 [==============================] - 4s 305ms/step - loss: 3.0085e-04 - val_loss: 0.0014

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
mean_squared_error(y_train, train_predict)
# Out:
# 32562.542968533755

# %%
mean_squared_error(y_test,test_predict)
# Out:
# 59802.28385275581

# %%
# Plotting 
look_back=100
trainPredictPlot = np.empty_like(y)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = np.empty_like(y)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(y)-1, :] = test_predict
# plot
plt.plot(scaler.inverse_transform(y))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 456

# %%
x_input=test_data[356:].reshape(1,-1)
x_input.shape
# Out:
# (1, 100)

# %%
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
_ = temp_input

# %%
# prediction for next 10 days
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
# Out:
# [0.92183185]
# 101
# 1 day input [0.76523263 0.77399616 0.79592248 0.81280976 0.80148282 0.81754682
#  0.82118498 0.77814263 0.79743275 0.78850824 0.80628864 0.83038338
#  0.83196229 0.83196229 0.81335905 0.83058917 0.85633255 0.86072601
#  0.8640211  0.86807139 0.88386096 0.88818535 0.89010776 0.88029111
#  0.88296806 0.8857825  0.8820074  0.87152737 0.87228387 0.86271902
#  0.87379754 0.86898135 0.86285651 0.87104539 0.84572246 0.81283009
#  0.82170728 0.84682322 0.84049238 0.81874868 0.83147802 0.84235009
#  0.864027   0.8619623  0.87820192 0.87723864 0.8793027  0.86162722
#  0.86555226 0.86286635 0.8657586  0.86396821 0.87512345 0.88345485
#  0.88386796 0.88985902 0.88118292 0.90087481 0.90920708 0.91099725
#  0.91092796 0.92642135 0.92655862 0.92717852 0.9280736  0.93330641
#  0.9345462  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395
#  0.94243737 0.95582038 0.95968334 0.96347811 0.96347811 0.95685535
#  0.93788522 0.91932886 0.92995164 0.93209045 0.95513075 0.94864614
#  0.94657706 0.94836986 0.96375396 0.96485757 0.97148033 0.97375574
#  0.97244492 0.98106856 0.98706071 0.99308041 0.99086663 0.99086663
#  0.99813202 1.         0.98754509 0.92183185]
# 1 day output [[0.9111878]]
# 2 day input [0.77399616 0.79592248 0.81280976 0.80148282 0.81754682 0.82118498
#  0.77814263 0.79743275 0.78850824 0.80628864 0.83038338 0.83196229
#  0.83196229 0.81335905 0.83058917 0.85633255 0.86072601 0.8640211
#  0.86807139 0.88386096 0.88818535 0.89010776 0.88029111 0.88296806
#  0.8857825  0.8820074  0.87152737 0.87228387 0.86271902 0.87379754
#  0.86898135 0.86285651 0.87104539 0.84572246 0.81283009 0.82170728
#  0.84682322 0.84049238 0.81874868 0.83147802 0.84235009 0.864027
#  0.8619623  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226
#  0.86286635 0.8657586  0.86396821 0.87512345 0.88345485 0.88386796
#  0.88985902 0.88118292 0.90087481 0.90920708 0.91099725 0.91092796
#  0.92642135 0.92655862 0.92717852 0.9280736  0.93330641 0.9345462
#  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395 0.94243737
#  0.95582038 0.95968334 0.96347811 0.96347811 0.95685535 0.93788522
#  0.91932886 0.92995164 0.93209045 0.95513075 0.94864614 0.94657706
#  0.94836986 0.96375396 0.96485757 0.97148033 0.97375574 0.97244492
#  0.98106856 0.98706071 0.99308041 0.99086663 0.99086663 0.99813202
#  1.         0.98754509 0.92183185 0.91118783]
# 2 day output [[0.89389557]]
# 3 day input [0.79592248 0.81280976 0.80148282 0.81754682 0.82118498 0.77814263
#  0.79743275 0.78850824 0.80628864 0.83038338 0.83196229 0.83196229
#  0.81335905 0.83058917 0.85633255 0.86072601 0.8640211  0.86807139
#  0.88386096 0.88818535 0.89010776 0.88029111 0.88296806 0.8857825
#  0.8820074  0.87152737 0.87228387 0.86271902 0.87379754 0.86898135
#  0.86285651 0.87104539 0.84572246 0.81283009 0.82170728 0.84682322
#  0.84049238 0.81874868 0.83147802 0.84235009 0.864027   0.8619623
#  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226 0.86286635
#  0.8657586  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902
#  0.88118292 0.90087481 0.90920708 0.91099725 0.91092796 0.92642135
#  0.92655862 0.92717852 0.9280736  0.93330641 0.9345462  0.94988811
#  0.9521644  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038
#  0.95968334 0.96347811 0.96347811 0.95685535 0.93788522 0.91932886
#  0.92995164 0.93209045 0.95513075 0.94864614 0.94657706 0.94836986
#  0.96375396 0.96485757 0.97148033 0.97375574 0.97244492 0.98106856
#  0.98706071 0.99308041 0.99086663 0.99086663 0.99813202 1.
#  0.98754509 0.92183185 0.91118783 0.89389557]
# 3 day output [[0.8735706]]
# 4 day input [0.81280976 0.80148282 0.81754682 0.82118498 0.77814263 0.79743275
#  0.78850824 0.80628864 0.83038338 0.83196229 0.83196229 0.81335905
#  0.83058917 0.85633255 0.86072601 0.8640211  0.86807139 0.88386096
#  0.88818535 0.89010776 0.88029111 0.88296806 0.8857825  0.8820074
#  0.87152737 0.87228387 0.86271902 0.87379754 0.86898135 0.86285651
#  0.87104539 0.84572246 0.81283009 0.82170728 0.84682322 0.84049238
#  0.81874868 0.83147802 0.84235009 0.864027   0.8619623  0.87820192
#  0.87723864 0.8793027  0.86162722 0.86555226 0.86286635 0.8657586
#  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902 0.88118292
#  0.90087481 0.90920708 0.91099725 0.91092796 0.92642135 0.92655862
#  0.92717852 0.9280736  0.93330641 0.9345462  0.94988811 0.9521644
#  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038 0.95968334
#  0.96347811 0.96347811 0.95685535 0.93788522 0.91932886 0.92995164
#  0.93209045 0.95513075 0.94864614 0.94657706 0.94836986 0.96375396
#  0.96485757 0.97148033 0.97375574 0.97244492 0.98106856 0.98706071
#  0.99308041 0.99086663 0.99086663 0.99813202 1.         0.98754509
#  0.92183185 0.91118783 0.89389557 0.87357062]
# 4 day output [[0.8529303]]
# 5 day input [0.80148282 0.81754682 0.82118498 0.77814263 0.79743275 0.78850824
#  0.80628864 0.83038338 0.83196229 0.83196229 0.81335905 0.83058917
#  0.85633255 0.86072601 0.8640211  0.86807139 0.88386096 0.88818535
#  0.89010776 0.88029111 0.88296806 0.8857825  0.8820074  0.87152737
#  0.87228387 0.86271902 0.87379754 0.86898135 0.86285651 0.87104539
#  0.84572246 0.81283009 0.82170728 0.84682322 0.84049238 0.81874868
#  0.83147802 0.84235009 0.864027   0.8619623  0.87820192 0.87723864
#  0.8793027  0.86162722 0.86555226 0.86286635 0.8657586  0.86396821
#  0.87512345 0.88345485 0.88386796 0.88985902 0.88118292 0.90087481
#  0.90920708 0.91099725 0.91092796 0.92642135 0.92655862 0.92717852
#  0.9280736  0.93330641 0.9345462  0.94988811 0.9521644  0.94567957
#  0.93788522 0.93457395 0.94243737 0.95582038 0.95968334 0.96347811
#  0.96347811 0.95685535 0.93788522 0.91932886 0.92995164 0.93209045
#  0.95513075 0.94864614 0.94657706 0.94836986 0.96375396 0.96485757
#  0.97148033 0.97375574 0.97244492 0.98106856 0.98706071 0.99308041
#  0.99086663 0.99086663 0.99813202 1.         0.98754509 0.92183185
#  0.91118783 0.89389557 0.87357062 0.85293031]
# 5 day output [[0.8336539]]
# 6 day input [0.81754682 0.82118498 0.77814263 0.79743275 0.78850824 0.80628864
#  0.83038338 0.83196229 0.83196229 0.81335905 0.83058917 0.85633255
#  0.86072601 0.8640211  0.86807139 0.88386096 0.88818535 0.89010776
#  0.88029111 0.88296806 0.8857825  0.8820074  0.87152737 0.87228387
#  0.86271902 0.87379754 0.86898135 0.86285651 0.87104539 0.84572246
#  0.81283009 0.82170728 0.84682322 0.84049238 0.81874868 0.83147802
#  0.84235009 0.864027   0.8619623  0.87820192 0.87723864 0.8793027
#  0.86162722 0.86555226 0.86286635 0.8657586  0.86396821 0.87512345
#  0.88345485 0.88386796 0.88985902 0.88118292 0.90087481 0.90920708
#  0.91099725 0.91092796 0.92642135 0.92655862 0.92717852 0.9280736
#  0.93330641 0.9345462  0.94988811 0.9521644  0.94567957 0.93788522
#  0.93457395 0.94243737 0.95582038 0.95968334 0.96347811 0.96347811
#  0.95685535 0.93788522 0.91932886 0.92995164 0.93209045 0.95513075
#  0.94864614 0.94657706 0.94836986 0.96375396 0.96485757 0.97148033
#  0.97375574 0.97244492 0.98106856 0.98706071 0.99308041 0.99086663
#  0.99086663 0.99813202 1.         0.98754509 0.92183185 0.91118783
#  0.89389557 0.87357062 0.85293031 0.83365393]
# 6 day output [[0.81664926]]
# 7 day input [0.82118498 0.77814263 0.79743275 0.78850824 0.80628864 0.83038338
#  0.83196229 0.83196229 0.81335905 0.83058917 0.85633255 0.86072601
#  0.8640211  0.86807139 0.88386096 0.88818535 0.89010776 0.88029111
#  0.88296806 0.8857825  0.8820074  0.87152737 0.87228387 0.86271902
#  0.87379754 0.86898135 0.86285651 0.87104539 0.84572246 0.81283009
#  0.82170728 0.84682322 0.84049238 0.81874868 0.83147802 0.84235009
#  0.864027   0.8619623  0.87820192 0.87723864 0.8793027  0.86162722
#  0.86555226 0.86286635 0.8657586  0.86396821 0.87512345 0.88345485
#  0.88386796 0.88985902 0.88118292 0.90087481 0.90920708 0.91099725
#  0.91092796 0.92642135 0.92655862 0.92717852 0.9280736  0.93330641
#  0.9345462  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395
#  0.94243737 0.95582038 0.95968334 0.96347811 0.96347811 0.95685535
#  0.93788522 0.91932886 0.92995164 0.93209045 0.95513075 0.94864614
#  0.94657706 0.94836986 0.96375396 0.96485757 0.97148033 0.97375574
#  0.97244492 0.98106856 0.98706071 0.99308041 0.99086663 0.99086663
#  0.99813202 1.         0.98754509 0.92183185 0.91118783 0.89389557
#  0.87357062 0.85293031 0.83365393 0.81664926]
# 7 day output [[0.8023369]]
# 8 day input [0.77814263 0.79743275 0.78850824 0.80628864 0.83038338 0.83196229
#  0.83196229 0.81335905 0.83058917 0.85633255 0.86072601 0.8640211
#  0.86807139 0.88386096 0.88818535 0.89010776 0.88029111 0.88296806
#  0.8857825  0.8820074  0.87152737 0.87228387 0.86271902 0.87379754
#  0.86898135 0.86285651 0.87104539 0.84572246 0.81283009 0.82170728
#  0.84682322 0.84049238 0.81874868 0.83147802 0.84235009 0.864027
#  0.8619623  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226
#  0.86286635 0.8657586  0.86396821 0.87512345 0.88345485 0.88386796
#  0.88985902 0.88118292 0.90087481 0.90920708 0.91099725 0.91092796
#  0.92642135 0.92655862 0.92717852 0.9280736  0.93330641 0.9345462
#  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395 0.94243737
#  0.95582038 0.95968334 0.96347811 0.96347811 0.95685535 0.93788522
#  0.91932886 0.92995164 0.93209045 0.95513075 0.94864614 0.94657706
#  0.94836986 0.96375396 0.96485757 0.97148033 0.97375574 0.97244492
#  0.98106856 0.98706071 0.99308041 0.99086663 0.99086663 0.99813202
#  1.         0.98754509 0.92183185 0.91118783 0.89389557 0.87357062
#  0.85293031 0.83365393 0.81664926 0.80233687]
# 8 day output [[0.7908421]]
# 9 day input [0.79743275 0.78850824 0.80628864 0.83038338 0.83196229 0.83196229
#  0.81335905 0.83058917 0.85633255 0.86072601 0.8640211  0.86807139
#  0.88386096 0.88818535 0.89010776 0.88029111 0.88296806 0.8857825
#  0.8820074  0.87152737 0.87228387 0.86271902 0.87379754 0.86898135
#  0.86285651 0.87104539 0.84572246 0.81283009 0.82170728 0.84682322
#  0.84049238 0.81874868 0.83147802 0.84235009 0.864027   0.8619623
#  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226 0.86286635
#  0.8657586  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902
#  0.88118292 0.90087481 0.90920708 0.91099725 0.91092796 0.92642135
#  0.92655862 0.92717852 0.9280736  0.93330641 0.9345462  0.94988811
#  0.9521644  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038
#  0.95968334 0.96347811 0.96347811 0.95685535 0.93788522 0.91932886
#  0.92995164 0.93209045 0.95513075 0.94864614 0.94657706 0.94836986
#  0.96375396 0.96485757 0.97148033 0.97375574 0.97244492 0.98106856
#  0.98706071 0.99308041 0.99086663 0.99086663 0.99813202 1.
#  0.98754509 0.92183185 0.91118783 0.89389557 0.87357062 0.85293031
#  0.83365393 0.81664926 0.80233687 0.79084212]
# 9 day output [[0.78210866]]
# 10 day input [0.78850824 0.80628864 0.83038338 0.83196229 0.83196229 0.81335905
#  0.83058917 0.85633255 0.86072601 0.8640211  0.86807139 0.88386096
#  0.88818535 0.89010776 0.88029111 0.88296806 0.8857825  0.8820074
#  0.87152737 0.87228387 0.86271902 0.87379754 0.86898135 0.86285651
#  0.87104539 0.84572246 0.81283009 0.82170728 0.84682322 0.84049238
#  0.81874868 0.83147802 0.84235009 0.864027   0.8619623  0.87820192
#  0.87723864 0.8793027  0.86162722 0.86555226 0.86286635 0.8657586
#  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902 0.88118292
#  0.90087481 0.90920708 0.91099725 0.91092796 0.92642135 0.92655862
#  0.92717852 0.9280736  0.93330641 0.9345462  0.94988811 0.9521644
#  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038 0.95968334
#  0.96347811 0.96347811 0.95685535 0.93788522 0.91932886 0.92995164
#  0.93209045 0.95513075 0.94864614 0.94657706 0.94836986 0.96375396
#  0.96485757 0.97148033 0.97375574 0.97244492 0.98106856 0.98706071
#  0.99308041 0.99086663 0.99086663 0.99813202 1.         0.98754509
#  0.92183185 0.91118783 0.89389557 0.87357062 0.85293031 0.83365393
#  0.81664926 0.80233687 0.79084212 0.78210866]
# 10 day output [[0.77596277]]
# 11 day input [0.80628864 0.83038338 0.83196229 0.83196229 0.81335905 0.83058917
#  0.85633255 0.86072601 0.8640211  0.86807139 0.88386096 0.88818535
#  0.89010776 0.88029111 0.88296806 0.8857825  0.8820074  0.87152737
#  0.87228387 0.86271902 0.87379754 0.86898135 0.86285651 0.87104539
#  0.84572246 0.81283009 0.82170728 0.84682322 0.84049238 0.81874868
#  0.83147802 0.84235009 0.864027   0.8619623  0.87820192 0.87723864
#  0.8793027  0.86162722 0.86555226 0.86286635 0.8657586  0.86396821
#  0.87512345 0.88345485 0.88386796 0.88985902 0.88118292 0.90087481
#  0.90920708 0.91099725 0.91092796 0.92642135 0.92655862 0.92717852
#  0.9280736  0.93330641 0.9345462  0.94988811 0.9521644  0.94567957
#  0.93788522 0.93457395 0.94243737 0.95582038 0.95968334 0.96347811
#  0.96347811 0.95685535 0.93788522 0.91932886 0.92995164 0.93209045
#  0.95513075 0.94864614 0.94657706 0.94836986 0.96375396 0.96485757
#  0.97148033 0.97375574 0.97244492 0.98106856 0.98706071 0.99308041
#  0.99086663 0.99086663 0.99813202 1.         0.98754509 0.92183185
#  0.91118783 0.89389557 0.87357062 0.85293031 0.83365393 0.81664926
#  0.80233687 0.79084212 0.78210866 0.77596277]
# 11 day output [[0.77215415]]
# 12 day input [0.83038338 0.83196229 0.83196229 0.81335905 0.83058917 0.85633255
#  0.86072601 0.8640211  0.86807139 0.88386096 0.88818535 0.89010776
#  0.88029111 0.88296806 0.8857825  0.8820074  0.87152737 0.87228387
#  0.86271902 0.87379754 0.86898135 0.86285651 0.87104539 0.84572246
#  0.81283009 0.82170728 0.84682322 0.84049238 0.81874868 0.83147802
#  0.84235009 0.864027   0.8619623  0.87820192 0.87723864 0.8793027
#  0.86162722 0.86555226 0.86286635 0.8657586  0.86396821 0.87512345
#  0.88345485 0.88386796 0.88985902 0.88118292 0.90087481 0.90920708
#  0.91099725 0.91092796 0.92642135 0.92655862 0.92717852 0.9280736
#  0.93330641 0.9345462  0.94988811 0.9521644  0.94567957 0.93788522
#  0.93457395 0.94243737 0.95582038 0.95968334 0.96347811 0.96347811
#  0.95685535 0.93788522 0.91932886 0.92995164 0.93209045 0.95513075
#  0.94864614 0.94657706 0.94836986 0.96375396 0.96485757 0.97148033
#  0.97375574 0.97244492 0.98106856 0.98706071 0.99308041 0.99086663
#  0.99086663 0.99813202 1.         0.98754509 0.92183185 0.91118783
#  0.89389557 0.87357062 0.85293031 0.83365393 0.81664926 0.80233687
#  0.79084212 0.78210866 0.77596277 0.77215415]
# 12 day output [[0.770382]]
# 13 day input [0.83196229 0.83196229 0.81335905 0.83058917 0.85633255 0.86072601
#  0.8640211  0.86807139 0.88386096 0.88818535 0.89010776 0.88029111
#  0.88296806 0.8857825  0.8820074  0.87152737 0.87228387 0.86271902
#  0.87379754 0.86898135 0.86285651 0.87104539 0.84572246 0.81283009
#  0.82170728 0.84682322 0.84049238 0.81874868 0.83147802 0.84235009
#  0.864027   0.8619623  0.87820192 0.87723864 0.8793027  0.86162722
#  0.86555226 0.86286635 0.8657586  0.86396821 0.87512345 0.88345485
#  0.88386796 0.88985902 0.88118292 0.90087481 0.90920708 0.91099725
#  0.91092796 0.92642135 0.92655862 0.92717852 0.9280736  0.93330641
#  0.9345462  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395
#  0.94243737 0.95582038 0.95968334 0.96347811 0.96347811 0.95685535
#  0.93788522 0.91932886 0.92995164 0.93209045 0.95513075 0.94864614
#  0.94657706 0.94836986 0.96375396 0.96485757 0.97148033 0.97375574
#  0.97244492 0.98106856 0.98706071 0.99308041 0.99086663 0.99086663
#  0.99813202 1.         0.98754509 0.92183185 0.91118783 0.89389557
#  0.87357062 0.85293031 0.83365393 0.81664926 0.80233687 0.79084212
#  0.78210866 0.77596277 0.77215415 0.77038199]
# 13 day output [[0.77031404]]
# 14 day input [0.83196229 0.81335905 0.83058917 0.85633255 0.86072601 0.8640211
#  0.86807139 0.88386096 0.88818535 0.89010776 0.88029111 0.88296806
#  0.8857825  0.8820074  0.87152737 0.87228387 0.86271902 0.87379754
#  0.86898135 0.86285651 0.87104539 0.84572246 0.81283009 0.82170728
#  0.84682322 0.84049238 0.81874868 0.83147802 0.84235009 0.864027
#  0.8619623  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226
#  0.86286635 0.8657586  0.86396821 0.87512345 0.88345485 0.88386796
#  0.88985902 0.88118292 0.90087481 0.90920708 0.91099725 0.91092796
#  0.92642135 0.92655862 0.92717852 0.9280736  0.93330641 0.9345462
#  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395 0.94243737
#  0.95582038 0.95968334 0.96347811 0.96347811 0.95685535 0.93788522
#  0.91932886 0.92995164 0.93209045 0.95513075 0.94864614 0.94657706
#  0.94836986 0.96375396 0.96485757 0.97148033 0.97375574 0.97244492
#  0.98106856 0.98706071 0.99308041 0.99086663 0.99086663 0.99813202
#  1.         0.98754509 0.92183185 0.91118783 0.89389557 0.87357062
#  0.85293031 0.83365393 0.81664926 0.80233687 0.79084212 0.78210866
#  0.77596277 0.77215415 0.77038199 0.77031404]
# 14 day output [[0.7716028]]
# 15 day input [0.81335905 0.83058917 0.85633255 0.86072601 0.8640211  0.86807139
#  0.88386096 0.88818535 0.89010776 0.88029111 0.88296806 0.8857825
#  0.8820074  0.87152737 0.87228387 0.86271902 0.87379754 0.86898135
#  0.86285651 0.87104539 0.84572246 0.81283009 0.82170728 0.84682322
#  0.84049238 0.81874868 0.83147802 0.84235009 0.864027   0.8619623
#  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226 0.86286635
#  0.8657586  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902
#  0.88118292 0.90087481 0.90920708 0.91099725 0.91092796 0.92642135
#  0.92655862 0.92717852 0.9280736  0.93330641 0.9345462  0.94988811
#  0.9521644  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038
#  0.95968334 0.96347811 0.96347811 0.95685535 0.93788522 0.91932886
#  0.92995164 0.93209045 0.95513075 0.94864614 0.94657706 0.94836986
#  0.96375396 0.96485757 0.97148033 0.97375574 0.97244492 0.98106856
#  0.98706071 0.99308041 0.99086663 0.99086663 0.99813202 1.
#  0.98754509 0.92183185 0.91118783 0.89389557 0.87357062 0.85293031
#  0.83365393 0.81664926 0.80233687 0.79084212 0.78210866 0.77596277
#  0.77215415 0.77038199 0.77031404 0.77160281]
# 15 day output [[0.77389646]]
# 16 day input [0.83058917 0.85633255 0.86072601 0.8640211  0.86807139 0.88386096
#  0.88818535 0.89010776 0.88029111 0.88296806 0.8857825  0.8820074
#  0.87152737 0.87228387 0.86271902 0.87379754 0.86898135 0.86285651
#  0.87104539 0.84572246 0.81283009 0.82170728 0.84682322 0.84049238
#  0.81874868 0.83147802 0.84235009 0.864027   0.8619623  0.87820192
#  0.87723864 0.8793027  0.86162722 0.86555226 0.86286635 0.8657586
#  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902 0.88118292
#  0.90087481 0.90920708 0.91099725 0.91092796 0.92642135 0.92655862
#  0.92717852 0.9280736  0.93330641 0.9345462  0.94988811 0.9521644
#  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038 0.95968334
#  0.96347811 0.96347811 0.95685535 0.93788522 0.91932886 0.92995164
#  0.93209045 0.95513075 0.94864614 0.94657706 0.94836986 0.96375396
#  0.96485757 0.97148033 0.97375574 0.97244492 0.98106856 0.98706071
#  0.99308041 0.99086663 0.99086663 0.99813202 1.         0.98754509
#  0.92183185 0.91118783 0.89389557 0.87357062 0.85293031 0.83365393
#  0.81664926 0.80233687 0.79084212 0.78210866 0.77596277 0.77215415
#  0.77038199 0.77031404 0.77160281 0.77389646]
# 16 day output [[0.77684885]]
# 17 day input [0.85633255 0.86072601 0.8640211  0.86807139 0.88386096 0.88818535
#  0.89010776 0.88029111 0.88296806 0.8857825  0.8820074  0.87152737
#  0.87228387 0.86271902 0.87379754 0.86898135 0.86285651 0.87104539
#  0.84572246 0.81283009 0.82170728 0.84682322 0.84049238 0.81874868
#  0.83147802 0.84235009 0.864027   0.8619623  0.87820192 0.87723864
#  0.8793027  0.86162722 0.86555226 0.86286635 0.8657586  0.86396821
#  0.87512345 0.88345485 0.88386796 0.88985902 0.88118292 0.90087481
#  0.90920708 0.91099725 0.91092796 0.92642135 0.92655862 0.92717852
#  0.9280736  0.93330641 0.9345462  0.94988811 0.9521644  0.94567957
#  0.93788522 0.93457395 0.94243737 0.95582038 0.95968334 0.96347811
#  0.96347811 0.95685535 0.93788522 0.91932886 0.92995164 0.93209045
#  0.95513075 0.94864614 0.94657706 0.94836986 0.96375396 0.96485757
#  0.97148033 0.97375574 0.97244492 0.98106856 0.98706071 0.99308041
#  0.99086663 0.99086663 0.99813202 1.         0.98754509 0.92183185
#  0.91118783 0.89389557 0.87357062 0.85293031 0.83365393 0.81664926
#  0.80233687 0.79084212 0.78210866 0.77596277 0.77215415 0.77038199
#  0.77031404 0.77160281 0.77389646 0.77684885]
# 17 day output [[0.7801288]]
# 18 day input [0.86072601 0.8640211  0.86807139 0.88386096 0.88818535 0.89010776
#  0.88029111 0.88296806 0.8857825  0.8820074  0.87152737 0.87228387
#  0.86271902 0.87379754 0.86898135 0.86285651 0.87104539 0.84572246
#  0.81283009 0.82170728 0.84682322 0.84049238 0.81874868 0.83147802
#  0.84235009 0.864027   0.8619623  0.87820192 0.87723864 0.8793027
#  0.86162722 0.86555226 0.86286635 0.8657586  0.86396821 0.87512345
#  0.88345485 0.88386796 0.88985902 0.88118292 0.90087481 0.90920708
#  0.91099725 0.91092796 0.92642135 0.92655862 0.92717852 0.9280736
#  0.93330641 0.9345462  0.94988811 0.9521644  0.94567957 0.93788522
#  0.93457395 0.94243737 0.95582038 0.95968334 0.96347811 0.96347811
#  0.95685535 0.93788522 0.91932886 0.92995164 0.93209045 0.95513075
#  0.94864614 0.94657706 0.94836986 0.96375396 0.96485757 0.97148033
#  0.97375574 0.97244492 0.98106856 0.98706071 0.99308041 0.99086663
#  0.99086663 0.99813202 1.         0.98754509 0.92183185 0.91118783
#  0.89389557 0.87357062 0.85293031 0.83365393 0.81664926 0.80233687
#  0.79084212 0.78210866 0.77596277 0.77215415 0.77038199 0.77031404
#  0.77160281 0.77389646 0.77684885 0.78012878]
# 18 day output [[0.78342885]]
# 19 day input [0.8640211  0.86807139 0.88386096 0.88818535 0.89010776 0.88029111
#  0.88296806 0.8857825  0.8820074  0.87152737 0.87228387 0.86271902
#  0.87379754 0.86898135 0.86285651 0.87104539 0.84572246 0.81283009
#  0.82170728 0.84682322 0.84049238 0.81874868 0.83147802 0.84235009
#  0.864027   0.8619623  0.87820192 0.87723864 0.8793027  0.86162722
#  0.86555226 0.86286635 0.8657586  0.86396821 0.87512345 0.88345485
#  0.88386796 0.88985902 0.88118292 0.90087481 0.90920708 0.91099725
#  0.91092796 0.92642135 0.92655862 0.92717852 0.9280736  0.93330641
#  0.9345462  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395
#  0.94243737 0.95582038 0.95968334 0.96347811 0.96347811 0.95685535
#  0.93788522 0.91932886 0.92995164 0.93209045 0.95513075 0.94864614
#  0.94657706 0.94836986 0.96375396 0.96485757 0.97148033 0.97375574
#  0.97244492 0.98106856 0.98706071 0.99308041 0.99086663 0.99086663
#  0.99813202 1.         0.98754509 0.92183185 0.91118783 0.89389557
#  0.87357062 0.85293031 0.83365393 0.81664926 0.80233687 0.79084212
#  0.78210866 0.77596277 0.77215415 0.77038199 0.77031404 0.77160281
#  0.77389646 0.77684885 0.78012878 0.78342885]
# 19 day output [[0.7864736]]
# 20 day input [0.86807139 0.88386096 0.88818535 0.89010776 0.88029111 0.88296806
#  0.8857825  0.8820074  0.87152737 0.87228387 0.86271902 0.87379754
#  0.86898135 0.86285651 0.87104539 0.84572246 0.81283009 0.82170728
#  0.84682322 0.84049238 0.81874868 0.83147802 0.84235009 0.864027
#  0.8619623  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226
#  0.86286635 0.8657586  0.86396821 0.87512345 0.88345485 0.88386796
#  0.88985902 0.88118292 0.90087481 0.90920708 0.91099725 0.91092796
#  0.92642135 0.92655862 0.92717852 0.9280736  0.93330641 0.9345462
#  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395 0.94243737
#  0.95582038 0.95968334 0.96347811 0.96347811 0.95685535 0.93788522
#  0.91932886 0.92995164 0.93209045 0.95513075 0.94864614 0.94657706
#  0.94836986 0.96375396 0.96485757 0.97148033 0.97375574 0.97244492
#  0.98106856 0.98706071 0.99308041 0.99086663 0.99086663 0.99813202
#  1.         0.98754509 0.92183185 0.91118783 0.89389557 0.87357062
#  0.85293031 0.83365393 0.81664926 0.80233687 0.79084212 0.78210866
#  0.77596277 0.77215415 0.77038199 0.77031404 0.77160281 0.77389646
#  0.77684885 0.78012878 0.78342885 0.78647357]
# 20 day output [[0.78902686]]
# 21 day input [0.88386096 0.88818535 0.89010776 0.88029111 0.88296806 0.8857825
#  0.8820074  0.87152737 0.87228387 0.86271902 0.87379754 0.86898135
#  0.86285651 0.87104539 0.84572246 0.81283009 0.82170728 0.84682322
#  0.84049238 0.81874868 0.83147802 0.84235009 0.864027   0.8619623
#  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226 0.86286635
#  0.8657586  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902
#  0.88118292 0.90087481 0.90920708 0.91099725 0.91092796 0.92642135
#  0.92655862 0.92717852 0.9280736  0.93330641 0.9345462  0.94988811
#  0.9521644  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038
#  0.95968334 0.96347811 0.96347811 0.95685535 0.93788522 0.91932886
#  0.92995164 0.93209045 0.95513075 0.94864614 0.94657706 0.94836986
#  0.96375396 0.96485757 0.97148033 0.97375574 0.97244492 0.98106856
#  0.98706071 0.99308041 0.99086663 0.99086663 0.99813202 1.
#  0.98754509 0.92183185 0.91118783 0.89389557 0.87357062 0.85293031
#  0.83365393 0.81664926 0.80233687 0.79084212 0.78210866 0.77596277
#  0.77215415 0.77038199 0.77031404 0.77160281 0.77389646 0.77684885
#  0.78012878 0.78342885 0.78647357 0.78902686]
# 21 day output [[0.7908989]]
# 22 day input [0.88818535 0.89010776 0.88029111 0.88296806 0.8857825  0.8820074
#  0.87152737 0.87228387 0.86271902 0.87379754 0.86898135 0.86285651
#  0.87104539 0.84572246 0.81283009 0.82170728 0.84682322 0.84049238
#  0.81874868 0.83147802 0.84235009 0.864027   0.8619623  0.87820192
#  0.87723864 0.8793027  0.86162722 0.86555226 0.86286635 0.8657586
#  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902 0.88118292
#  0.90087481 0.90920708 0.91099725 0.91092796 0.92642135 0.92655862
#  0.92717852 0.9280736  0.93330641 0.9345462  0.94988811 0.9521644
#  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038 0.95968334
#  0.96347811 0.96347811 0.95685535 0.93788522 0.91932886 0.92995164
#  0.93209045 0.95513075 0.94864614 0.94657706 0.94836986 0.96375396
#  0.96485757 0.97148033 0.97375574 0.97244492 0.98106856 0.98706071
#  0.99308041 0.99086663 0.99086663 0.99813202 1.         0.98754509
#  0.92183185 0.91118783 0.89389557 0.87357062 0.85293031 0.83365393
#  0.81664926 0.80233687 0.79084212 0.78210866 0.77596277 0.77215415
#  0.77038199 0.77031404 0.77160281 0.77389646 0.77684885 0.78012878
#  0.78342885 0.78647357 0.78902686 0.79089892]
# 22 day output [[0.7919512]]
# 23 day input [0.89010776 0.88029111 0.88296806 0.8857825  0.8820074  0.87152737
#  0.87228387 0.86271902 0.87379754 0.86898135 0.86285651 0.87104539
#  0.84572246 0.81283009 0.82170728 0.84682322 0.84049238 0.81874868
#  0.83147802 0.84235009 0.864027   0.8619623  0.87820192 0.87723864
#  0.8793027  0.86162722 0.86555226 0.86286635 0.8657586  0.86396821
#  0.87512345 0.88345485 0.88386796 0.88985902 0.88118292 0.90087481
#  0.90920708 0.91099725 0.91092796 0.92642135 0.92655862 0.92717852
#  0.9280736  0.93330641 0.9345462  0.94988811 0.9521644  0.94567957
#  0.93788522 0.93457395 0.94243737 0.95582038 0.95968334 0.96347811
#  0.96347811 0.95685535 0.93788522 0.91932886 0.92995164 0.93209045
#  0.95513075 0.94864614 0.94657706 0.94836986 0.96375396 0.96485757
#  0.97148033 0.97375574 0.97244492 0.98106856 0.98706071 0.99308041
#  0.99086663 0.99086663 0.99813202 1.         0.98754509 0.92183185
#  0.91118783 0.89389557 0.87357062 0.85293031 0.83365393 0.81664926
#  0.80233687 0.79084212 0.78210866 0.77596277 0.77215415 0.77038199
#  0.77031404 0.77160281 0.77389646 0.77684885 0.78012878 0.78342885
#  0.78647357 0.78902686 0.79089892 0.79195118]
# 23 day output [[0.7920985]]
# 24 day input [0.88029111 0.88296806 0.8857825  0.8820074  0.87152737 0.87228387
#  0.86271902 0.87379754 0.86898135 0.86285651 0.87104539 0.84572246
#  0.81283009 0.82170728 0.84682322 0.84049238 0.81874868 0.83147802
#  0.84235009 0.864027   0.8619623  0.87820192 0.87723864 0.8793027
#  0.86162722 0.86555226 0.86286635 0.8657586  0.86396821 0.87512345
#  0.88345485 0.88386796 0.88985902 0.88118292 0.90087481 0.90920708
#  0.91099725 0.91092796 0.92642135 0.92655862 0.92717852 0.9280736
#  0.93330641 0.9345462  0.94988811 0.9521644  0.94567957 0.93788522
#  0.93457395 0.94243737 0.95582038 0.95968334 0.96347811 0.96347811
#  0.95685535 0.93788522 0.91932886 0.92995164 0.93209045 0.95513075
#  0.94864614 0.94657706 0.94836986 0.96375396 0.96485757 0.97148033
#  0.97375574 0.97244492 0.98106856 0.98706071 0.99308041 0.99086663
#  0.99086663 0.99813202 1.         0.98754509 0.92183185 0.91118783
#  0.89389557 0.87357062 0.85293031 0.83365393 0.81664926 0.80233687
#  0.79084212 0.78210866 0.77596277 0.77215415 0.77038199 0.77031404
#  0.77160281 0.77389646 0.77684885 0.78012878 0.78342885 0.78647357
#  0.78902686 0.79089892 0.79195118 0.79209852]
# 24 day output [[0.79130965]]
# 25 day input [0.88296806 0.8857825  0.8820074  0.87152737 0.87228387 0.86271902
#  0.87379754 0.86898135 0.86285651 0.87104539 0.84572246 0.81283009
#  0.82170728 0.84682322 0.84049238 0.81874868 0.83147802 0.84235009
#  0.864027   0.8619623  0.87820192 0.87723864 0.8793027  0.86162722
#  0.86555226 0.86286635 0.8657586  0.86396821 0.87512345 0.88345485
#  0.88386796 0.88985902 0.88118292 0.90087481 0.90920708 0.91099725
#  0.91092796 0.92642135 0.92655862 0.92717852 0.9280736  0.93330641
#  0.9345462  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395
#  0.94243737 0.95582038 0.95968334 0.96347811 0.96347811 0.95685535
#  0.93788522 0.91932886 0.92995164 0.93209045 0.95513075 0.94864614
#  0.94657706 0.94836986 0.96375396 0.96485757 0.97148033 0.97375574
#  0.97244492 0.98106856 0.98706071 0.99308041 0.99086663 0.99086663
#  0.99813202 1.         0.98754509 0.92183185 0.91118783 0.89389557
#  0.87357062 0.85293031 0.83365393 0.81664926 0.80233687 0.79084212
#  0.78210866 0.77596277 0.77215415 0.77038199 0.77031404 0.77160281
#  0.77389646 0.77684885 0.78012878 0.78342885 0.78647357 0.78902686
#  0.79089892 0.79195118 0.79209852 0.79130965]
# 25 day output [[0.7896043]]
# 26 day input [0.8857825  0.8820074  0.87152737 0.87228387 0.86271902 0.87379754
#  0.86898135 0.86285651 0.87104539 0.84572246 0.81283009 0.82170728
#  0.84682322 0.84049238 0.81874868 0.83147802 0.84235009 0.864027
#  0.8619623  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226
#  0.86286635 0.8657586  0.86396821 0.87512345 0.88345485 0.88386796
#  0.88985902 0.88118292 0.90087481 0.90920708 0.91099725 0.91092796
#  0.92642135 0.92655862 0.92717852 0.9280736  0.93330641 0.9345462
#  0.94988811 0.9521644  0.94567957 0.93788522 0.93457395 0.94243737
#  0.95582038 0.95968334 0.96347811 0.96347811 0.95685535 0.93788522
#  0.91932886 0.92995164 0.93209045 0.95513075 0.94864614 0.94657706
#  0.94836986 0.96375396 0.96485757 0.97148033 0.97375574 0.97244492
#  0.98106856 0.98706071 0.99308041 0.99086663 0.99086663 0.99813202
#  1.         0.98754509 0.92183185 0.91118783 0.89389557 0.87357062
#  0.85293031 0.83365393 0.81664926 0.80233687 0.79084212 0.78210866
#  0.77596277 0.77215415 0.77038199 0.77031404 0.77160281 0.77389646
#  0.77684885 0.78012878 0.78342885 0.78647357 0.78902686 0.79089892
#  0.79195118 0.79209852 0.79130965 0.78960431]
# 26 day output [[0.7870498]]
# 27 day input [0.8820074  0.87152737 0.87228387 0.86271902 0.87379754 0.86898135
#  0.86285651 0.87104539 0.84572246 0.81283009 0.82170728 0.84682322
#  0.84049238 0.81874868 0.83147802 0.84235009 0.864027   0.8619623
#  0.87820192 0.87723864 0.8793027  0.86162722 0.86555226 0.86286635
#  0.8657586  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902
#  0.88118292 0.90087481 0.90920708 0.91099725 0.91092796 0.92642135
#  0.92655862 0.92717852 0.9280736  0.93330641 0.9345462  0.94988811
#  0.9521644  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038
#  0.95968334 0.96347811 0.96347811 0.95685535 0.93788522 0.91932886
#  0.92995164 0.93209045 0.95513075 0.94864614 0.94657706 0.94836986
#  0.96375396 0.96485757 0.97148033 0.97375574 0.97244492 0.98106856
#  0.98706071 0.99308041 0.99086663 0.99086663 0.99813202 1.
#  0.98754509 0.92183185 0.91118783 0.89389557 0.87357062 0.85293031
#  0.83365393 0.81664926 0.80233687 0.79084212 0.78210866 0.77596277
#  0.77215415 0.77038199 0.77031404 0.77160281 0.77389646 0.77684885
#  0.78012878 0.78342885 0.78647357 0.78902686 0.79089892 0.79195118
#  0.79209852 0.79130965 0.78960431 0.78704977]
# 27 day output [[0.7837512]]
# 28 day input [0.87152737 0.87228387 0.86271902 0.87379754 0.86898135 0.86285651
#  0.87104539 0.84572246 0.81283009 0.82170728 0.84682322 0.84049238
#  0.81874868 0.83147802 0.84235009 0.864027   0.8619623  0.87820192
#  0.87723864 0.8793027  0.86162722 0.86555226 0.86286635 0.8657586
#  0.86396821 0.87512345 0.88345485 0.88386796 0.88985902 0.88118292
#  0.90087481 0.90920708 0.91099725 0.91092796 0.92642135 0.92655862
#  0.92717852 0.9280736  0.93330641 0.9345462  0.94988811 0.9521644
#  0.94567957 0.93788522 0.93457395 0.94243737 0.95582038 0.95968334
#  0.96347811 0.96347811 0.95685535 0.93788522 0.91932886 0.92995164
#  0.93209045 0.95513075 0.94864614 0.94657706 0.94836986 0.96375396
#  0.96485757 0.97148033 0.97375574 0.97244492 0.98106856 0.98706071
#  0.99308041 0.99086663 0.99086663 0.99813202 1.         0.98754509
#  0.92183185 0.91118783 0.89389557 0.87357062 0.85293031 0.83365393
#  0.81664926 0.80233687 0.79084212 0.78210866 0.77596277 0.77215415
#  0.77038199 0.77031404 0.77160281 0.77389646 0.77684885 0.78012878
#  0.78342885 0.78647357 0.78902686 0.79089892 0.79195118 0.79209852
#  0.79130965 0.78960431 0.78704977 0.78375119]
# 28 day output [[0.7798453]]
# 29 day input [0.87228387 0.86271902 0.87379754 0.86898135 0.86285651 0.87104539
#  0.84572246 0.81283009 0.82170728 0.84682322 0.84049238 0.81874868
#  0.83147802 0.84235009 0.864027   0.8619623  0.87820192 0.87723864
#  0.8793027  0.86162722 0.86555226 0.86286635 0.8657586  0.86396821
#  0.87512345 0.88345485 0.88386796 0.88985902 0.88118292 0.90087481
#  0.90920708 0.91099725 0.91092796 0.92642135 0.92655862 0.92717852
#  0.9280736  0.93330641 0.9345462  0.94988811 0.9521644  0.94567957
#  0.93788522 0.93457395 0.94243737 0.95582038 0.95968334 0.96347811
#  0.96347811 0.95685535 0.93788522 0.91932886 0.92995164 0.93209045
#  0.95513075 0.94864614 0.94657706 0.94836986 0.96375396 0.96485757
#  0.97148033 0.97375574 0.97244492 0.98106856 0.98706071 0.99308041
#  0.99086663 0.99086663 0.99813202 1.         0.98754509 0.92183185
#  0.91118783 0.89389557 0.87357062 0.85293031 0.83365393 0.81664926
#  0.80233687 0.79084212 0.78210866 0.77596277 0.77215415 0.77038199
#  0.77031404 0.77160281 0.77389646 0.77684885 0.78012878 0.78342885
#  0.78647357 0.78902686 0.79089892 0.79195118 0.79209852 0.79130965
#  0.78960431 0.78704977 0.78375119 0.7798453 ]
# 29 day output [[0.7754895]]

# %%
day_new=np.arange(1,101)
day_pred=np.arange(101,131)

# %%
len(y)
# Out:
# 1302

# %%
plt.plot(day_new,scaler.inverse_transform(y[1202:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))

# %%
z=y.tolist()
z.extend(lst_output)
plt.plot(z[1202:])

# %%
z=scaler.inverse_transform(z).tolist()

# %%
plt.plot(z)
